# %%
#A1
for i in range(5):
  print('*'*(i+1))
# Out:
# *
# **
# ***
# ****
# *****

# %%
#A2
print('-'*20)
# Out:
# --------------------

# %%
#A3
line = '홀짝홀짝홀짝홀짝홀짝'
print(line[0:11:2])
# Out:
# 홀홀홀홀홀

# %%
#A4
sent = '        Hello everyone. Hi. This is my husband.   '
new_sent = sent.strip()
h_sum = new_sent.count('H') + new_sent.count('h')
print(new_sent)
print(h_sum)
# Out:
# Hello everyone. Hi. This is my husband.
# 4

# %%
#A5
phone_number = "010-1234-5678"
print(phone_number.replace('-', ' '))
# Out:
# 010 1234 5678

# %%
#A6
phone_number = "010-1234-5678"
print(phone_number[-4:])
# Out:
# 5678

# %%
#A7
file_name = "report.xlsx"
print(file_name.endswith(".xlsx"))
# Out:
# True

# %%
#A8
my = ['a', 'the', 'hello', 'name', 'hello', 'name', 'age']
delete_duplicate = set(my)
print(sorted(delete_duplicate))
# Out:
# ['a', 'age', 'hello', 'name', 'the']

# %%
#A9
movie = ['닥터 스트레인지', '슈퍼맨', '스파이더맨', '배트맨']
movie.remove("스파이더맨")
movie.remove("배트맨")
print(movie)
# Out:
# ['닥터 스트레인지', '슈퍼맨']

# %%
#A10
nums = [1, 2, 3, 4, 5]
print(sum(nums)/len(nums))
# Out:
# 3.0

# %%
#A11
interest = ['삼성전자', 'LG전자', 'Naver', 'SK하이닉스', '미래에셋대우']
print('/'.join(interest))
# Out:
# 삼성전자/LG전자/Naver/SK하이닉스/미래에셋대우

# %%
#A12
major = ['국문', '경영', '영상', '글경']
major.insert(2, "통계")
major.insert(5, "컬텍")
print(major)
# Out:
# ['국문', '경영', '통계', '영상', '글경', '컬텍']

# %%
#A13
ice = {'메로나': 1000,
       '폴로포': 1200,
       '빵빠레': 1800,
       '죠스바': 1200,
       '월드콘': 1500}
print("메로나 가격: ",ice['메로나'])
# Out:
# 메로나 가격:  1000

# %%
#A14
icecream = {'탱크보이': 1200, '폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000}
print(list(icecream.keys()))
# Out:
# ['탱크보이', '폴라포', '빵빠레', '월드콘', '메로나']

# %%
#A15
icecream = {'탱크보이': 1200, '폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000}
sum = 0
for i in icecream.values():
  sum += i
print(sum)
# Out:
# 6700
