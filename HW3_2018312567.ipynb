# %%
from nltk.corpus import inaugural
nltk.download('1789-Washington.txt')
print(inaugural.sents('1789-Washington.txt')[-1])
# Out:
# [nltk_data] Error loading 1789-Washington.txt: Package
# [nltk_data]     '1789-Washington.txt' not found in index
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-4-5836274f9e8d> in <module>()
#       1 from nltk.corpus import inaugural
#       2 nltk.download('1789-Washington.txt')
# ----> 3 print(inaugural.sents('1789-Washington.txt')[-1])
#
# /usr/local/lib/python3.7/dist-packages/nltk/corpus/reader/util.py in __getitem__(self, i)
#     245         else:
#     246             # Handle negative indices
# --> 247             if i < 0: i += len(self)
#     248             if i < 0: raise IndexError('index out of range')
#     249             # Check if it's in the cache.
#
# /usr/local/lib/python3.7/dist-packages/nltk/corpus/reader/util.py in __len__(self)
#     231             # iterate_from() sets self._len when it reaches the end
# ...
